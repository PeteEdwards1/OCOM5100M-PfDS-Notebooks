# %% [markdown]
# # Unit 2 – Practice & Consolidation Worksheet
#
# These exercises are for your own practice and are **not graded**. Work through them after completing the Unit 2 reading material. Attempt each exercise before revealing the answer.
#
# ## Exercise types
#
# | Type | What to do |
# |---|---|
# | Predict the output | Write what you think the code will print *before* running the cell |
# | Fix the bug | The code contains an error — find and correct it |
# | Fill in the blank | Complete the missing line(s) to produce the expected output |
# | Adapt and extend | A working example is given — modify it to solve a related problem |
#
# **Topics:** conditionals · loops · functions · object orientation · error handling
#
# ---
#
# ## Section 1 – Conditionals

# %% [markdown]
# ### Exercise 1.1 Predict the output
#
# A train fare system charges different rates depending on journey length. Trace through the conditions and write what you expect to be printed before running the cell.
#
# ```python
# distance_km = 45
#
# if distance_km < 10:
#     print("Short fare: £2.50")
# elif distance_km < 50:
#     print("Medium fare: £6.00")
# elif distance_km < 100:
#     print("Long fare: £10.00")
# else:
#     print("Extended fare: £15.00")
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Output: Medium fare: £6.00
# ```
#
# `distance_km < 10` is `False`, so Python moves to the next branch. `distance_km < 50` is `True` (45 < 50), so it prints the medium fare and skips all remaining branches — even though `distance_km < 100` would also be `True`. The first matching branch wins.
#
# </details>

# %% [markdown]
# ### Exercise 1.2 Fill in the blank
#
# A library system categorises books by how many times they have been borrowed. Complete the condition so that books borrowed 20 or more times are marked as popular.
#
# Expected output:
# ```
# Popular
# ```
#
# ```python
# borrow_count = 34
#
# if _______________:
#     status = "Popular"
# else:
#     status = "Standard"
#
# print(status)
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# if borrow_count >= 20:
# ```
#
# `>=` checks "greater than or equal to". Using `>` instead would incorrectly classify exactly 20 borrows as "Standard". When a threshold is inclusive, always use `>=` rather than `>`.
#
# </details>

# %% [markdown]
# ### Exercise 1.3 Fix the bug
#
# The code below should print the air quality description for a given pollution index. It contains two errors. Find and fix both.
#
# Expected output:
# ```
# Moderate
# ```
#
# ```python
# pollution_index = 75
#
# if pollution_index < 50
#     print("Good")
# elif pollution_index < 100:
#     print("Moderate")
# else
#     print("Poor")
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# if pollution_index < 50:
#     print("Good")
# elif pollution_index < 100:
#     print("Moderate")
# else:
#     print("Poor")
# ```
#
# Both `if` and `else` lines are missing a colon at the end. In Python, every `if`, `elif`, and `else` header must end with `:`. Missing colons cause a `SyntaxError`.
#
# </details>

# %% [markdown]
# ### Exercise 1.4 Predict the output
#
# A streaming platform checks eligibility before showing a film. What will this nested conditional print?
#
# ```python
# is_subscribed = True
# age = 15
# is_adult_content = True
#
# if is_subscribed:
#     if is_adult_content and age < 18:
#         print("Age restriction applies")
#     else:
#         print("Enjoy the film")
# else:
#     print("Please subscribe to continue")
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Output: Age restriction applies
# ```
#
# `is_subscribed` is `True`, so Python enters the outer block. Inside, `is_adult_content and age < 18` evaluates to `True and True`, which is `True`, so it prints the restriction message. Both conditions in an `and` expression must be `True` for the whole expression to be `True`.
#
# </details>

# %% [markdown]
# ### Exercise 1.5 Adapt and extend
#
# The code below assigns a shipping speed based on whether an order is urgent:
#
# ```python
# is_urgent = True
# if is_urgent:
#     print("Next day delivery")
# else:
#     print("Standard delivery")
# ```
#
# Adapt it to handle three membership tiers — `"gold"`, `"silver"`, and `"standard"` — with different estimated delivery days:
# - `"gold"` → `"Delivery in 1 day"`
# - `"silver"` → `"Delivery in 3 days"`
# - `"standard"` → `"Delivery in 7 days"`
# - anything else → `"Unknown membership tier"`
#
# Test it with `tier = "silver"`.
#
# ```python
# tier = "silver"
#
# # Your code here
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# if tier == "gold":
#     print("Delivery in 1 day")
# elif tier == "silver":
#     print("Delivery in 3 days")
# elif tier == "standard":
#     print("Delivery in 7 days")
# else:
#     print("Unknown membership tier")
# ```
#
# String comparisons with `==` are case-sensitive — `"Silver"` would not match `"silver"`. The `else` branch catches any value not matched above, which is good defensive practice: always handle unexpected inputs.
#
# </details>

# %% [markdown]
# ---
# ## Section 2 – Loops

# %% [markdown]
# ### Exercise 2.1 Predict the output
#
# A barcode scanner reads a sequence of digits. What will this loop print?
#
# ```python
# digits = [3, 0, 7, 2, 8]
# running_total = 0
#
# for d in digits:
#     running_total += d
#     print(running_total)
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # 3
# # 3
# # 10
# # 12
# # 20
# ```
#
# `running_total` is updated on each iteration, and `print` is called inside the loop, so it prints the cumulative sum after each digit is added: 3, 3+0=3, 3+7=10, 10+2=12, 12+8=20. Moving `print` outside the loop would print only the final total.
#
# </details>

# %% [markdown]
# ### Exercise 2.2 Fill in the blank
#
# A car park charges £2 per hour. Complete the loop to calculate the total charge for a list of parking durations (in hours).
#
# Expected output:
# ```
# Total charge: £22
# ```
#
# ```python
# durations = [1, 3, 2, 4, 1]
# total = 0
#
# for hours in durations:
#     _______________
#
# print(f"Total charge: £{total}")
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# total += hours * 2
# ```
#
# Each duration is multiplied by the hourly rate and added to the running total. `+=` is shorthand for `total = total + hours * 2`. Multiplication is evaluated before addition, so no parentheses are needed here.
#
# </details>

# %% [markdown]
# ### Exercise 2.3 Fix the bug
#
# The loop is meant to count how many passwords in the list are longer than 8 characters, but the counter is in the wrong place. Fix the indentation.
#
# Expected output:
# ```
# 3
# ```
#
# ```python
# passwords = ["abc", "securepass", "hello", "trustno1x", "qwerty", "P@ssw0rd!"]
# count = 0
#
# for pw in passwords:
#     if len(pw) > 8:
# count += 1
#
# print(count)
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# for pw in passwords:
#     if len(pw) > 8:
#         count += 1
# ```
#
# `count += 1` must be indented inside the `if` block. As written, it is outside the `if` and even outside the `for` loop entirely, so it only runs once after the loop ends, giving the wrong result. Correct indentation is essential in Python — it defines the structure of your code.
#
# </details>

# %% [markdown]
# ### Exercise 2.4 Predict the output
#
# A server retries a connection until it succeeds or runs out of attempts. What will this loop print?
#
# ```python
# attempts = 0
# max_attempts = 5
# connected = False
#
# while attempts < max_attempts and not connected:
#     attempts += 1
#     if attempts == 3:
#         connected = True
#     print(f"Attempt {attempts}: {'connected' if connected else 'failed'}")
#
# print(f"Done after {attempts} attempt(s)")
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Attempt 1: failed
# # Attempt 2: failed
# # Attempt 3: connected
# # Done after 3 attempt(s)
# ```
#
# The loop condition checks both `attempts < max_attempts` and `not connected`. On attempt 3, `connected` is set to `True`, so `not connected` becomes `False` — the loop exits after printing attempt 3. The `while` loop is ideal here because the number of iterations is not known in advance.
#
# </details>

# %% [markdown]
# ### Exercise 2.5 Adapt and extend
#
# The code below loops through a list of sensor readings and prints each one:
#
# ```python
# readings = [12.4, 9.8, 15.1, 7.3, 11.0]
# for r in readings:
#     print(r)
# ```
#
# Adapt it to:
# 1. Skip any reading below 10.0 using `continue`.
# 2. Stop the loop entirely if a reading exceeds 14.0 using `break`.
# 3. Print the readings that pass both checks.
#
# Expected output:
# ```
# 12.4
# ```
#
# ```python
# readings = [12.4, 9.8, 15.1, 7.3, 11.0]
#
# # Your code here
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# for r in readings:
#     if r > 14.0:
#         break
#     if r < 10.0:
#         continue
#     print(r)
# ```
#
# Order matters: check `break` before `continue`. If you checked `continue` first, a reading above 14.0 that is also above 10.0 would print before the loop had a chance to break. `break` exits the loop immediately; `continue` skips to the next iteration. `12.4` is the only value that passes both checks before 15.1 triggers the break.
#
# </details>

# %% [markdown]
# ---
# ## Section 3 – Functions

# %% [markdown]
# ### Exercise 3.1 Predict the output
#
# What will each call print? Pay attention to how the default argument behaves.
#
# ```python
# def format_price(amount, currency="GBP", include_symbol=True):
#     symbol = "£" if currency == "GBP" else "$"
#     if include_symbol:
#         return f"{symbol}{amount:.2f}"
#     return f"{amount:.2f}"
#
# print(format_price(9.5))
# print(format_price(9.5, "USD"))
# print(format_price(9.5, include_symbol=False))
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # £9.50
# # $9.50
# # 9.50
# ```
#
# The first call uses both defaults. The second overrides `currency` positionally — `"USD"` triggers the `else` branch, giving `$`. The third uses a keyword argument to override only `include_symbol`, leaving `currency` at its default `"GBP"`, so the symbol would be `£` but it is not shown. Keyword arguments let you skip over parameters you do not want to change.
#
# </details>

# %% [markdown]
# ### Exercise 3.2 Fill in the blank
#
# Complete the function that returns the number of words in a string. Words are separated by spaces.
#
# Expected output:
# ```
# 5
# 1
# 0
# ```
#
# ```python
# def word_count(text):
#     if not text.strip():
#         return 0
#     return _______________
#
# print(word_count("the quick brown fox jumps"))
# print(word_count("hello"))
# print(word_count("   "))
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# return len(text.split())
# ```
#
# `str.split()` with no arguments splits on any whitespace and ignores leading, trailing, and multiple spaces — including strings that contain only spaces, for which it returns an empty list. This means the `if not text.strip()` guard is not strictly necessary, since `len(text.split())` would return `0` for a blank string on its own. However, the guard is kept here to make the intent explicit: a reader scanning the function can immediately see that blank input is handled as a special case, without having to reason about how `split()` behaves internally.
# </details>

# %% [markdown]
# ### Exercise 3.3 Fix the bug
#
# The function is supposed to return both the minimum and maximum values from a list, but it only ever returns the minimum. Fix it.
#
# Expected output:
# ```
# 2 19
# ```
#
# ```python
# def min_max(numbers):
#     return min(numbers)
#     return max(numbers)
#
# low, high = min_max([5, 2, 19, 8, 11])
# print(low, high)
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# def min_max(numbers):
#     return min(numbers), max(numbers)
# ```
#
# A `return` statement exits the function immediately — any code after the first `return` is unreachable. To return two values, return them as a tuple: `return min(numbers), max(numbers)`. Python automatically unpacks this into `low, high` on the calling side.
#
# </details>

# %% [markdown]
# ### Exercise 3.4 Predict the output
#
# What will be printed, and why does the second `print` produce a different result from what you might expect?
#
# ```python
# readings = [4.1, 7.8, 2.3]
#
# def add_reading(data, value):
#     data.append(value)
#
# result = add_reading(readings, 9.9)
#
# print(readings)
# print(result)
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # [4.1, 7.8, 2.3, 9.9]
# # None
# ```
#
# Lists are **mutable** — when you pass one to a function, the function receives a reference to the same object, not a copy. `data.append(value)` modifies the original `readings` list in place, which is why the first print shows the updated list. The function has no `return` statement, so it returns `None`, which is what the second print shows.
#
# </details>

# %% [markdown]
# ### Exercise 3.5 Adapt and extend
#
# The function below calculates a discount on a single price:
#
# ```python
# def apply_discount(price, discount_pct):
#     return price * (1 - discount_pct / 100)
#
# print(apply_discount(50, 20))  # 40.0
# ```
#
# Write a second function `apply_to_all(prices, discount_pct)` that takes a list of prices and returns a new list with the discount applied to each one. Use `apply_discount` inside your new function.
#
# Expected output:
# ```
# [40.0, 32.0, 8.0]
# ```
#
# ```python
# def apply_discount(price, discount_pct):
#     return price * (1 - discount_pct / 100)
#
# def apply_to_all(prices, discount_pct):
#     # Your code here
#
# print(apply_to_all([50, 40, 10], 20))
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# def apply_to_all(prices, discount_pct):
#     return [apply_discount(p, discount_pct) for p in prices]
# ```
#
# A list comprehension is a concise way to apply a function to every element of a list and collect the results. `apply_discount(p, discount_pct)` is called for each price `p`, with the shared `discount_pct` passed each time. A `for` loop with `append` is equally valid.
#
# </details>

# %% [markdown]
# ---
# ## Section 4 – Object Orientation

# %% [markdown]
# ### Exercise 4.1 Predict the output
#
# Read the class definition carefully. What will each line print?
#
# ```python
# class BankAccount:
#     def __init__(self, owner, balance=0):
#         self.owner = owner
#         self.balance = balance
#
#     def deposit(self, amount):
#         self.balance += amount
#
#     def summary(self):
#         return f"{self.owner}: £{self.balance:.2f}"
#
# acc = BankAccount("Priya", 100)
# acc.deposit(50)
# acc.deposit(25)
#
# print(acc.balance)
# print(acc.summary())
# print(type(acc))
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # 175
# # Priya: £175.00
# # <class '__main__.BankAccount'>
# ```
#
# `__init__` sets `self.balance = 100` when the account is created. Each call to `deposit` adds to `self.balance` in place. `summary` uses an f-string with `:.2f` to format the balance to two decimal places. `type(acc)` shows the class the instance belongs to.
#
# </details>

# %% [markdown]
# ### Exercise 4.2 Fill in the blank
#
# Complete the `Podcast` class with a `duration_str` method that returns the length in `"Xh Ym"` format.
#
# Expected output:
# ```
# Syntax Error: 1h 23m
# Hidden Brain: 0h 45m
# ```
#
# ```python
# class Podcast:
#     def __init__(self, title, duration_minutes):
#         self.title = title
#         self.duration_minutes = duration_minutes
#
#     def duration_str(self):
#         hours = _______________
#         minutes = _______________
#         return f"{self.title}: {hours}h {minutes}m"
#
# p1 = Podcast("Syntax Error", 83)
# p2 = Podcast("Hidden Brain", 45)
# print(p1.duration_str())
# print(p2.duration_str())
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# hours = self.duration_minutes // 60
# minutes = self.duration_minutes % 60
# ```
#
# `//` is integer (floor) division — it gives the number of complete hours. `%` is the modulo operator — it gives the remainder, i.e. the leftover minutes. Both must use `self.duration_minutes` to access the instance attribute.
#
# </details>

# %% [markdown]
# ### Exercise 4.3 Fix the bug
#
# The `FlightBooking` class raises an error when used. Find and fix it.
#
# Expected output:
# ```
# BA271 | Seats booked: 2
# ```
#
# ```python
# class FlightBooking:
#     def __init__(self, flight_number):
#         self.flight_number = flight_number
#         self.seats_booked = 0
#
#     def book(seats):
#         self.seats_booked += seats
#
#     def status(self):
#         return f"{self.flight_number} | Seats booked: {self.seats_booked}"
#
# f = FlightBooking("BA271")
# f.book(2)
# print(f.status())
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# def book(self, seats):
#     self.seats_booked += seats
# ```
#
# The `book` method is missing `self` as its first parameter. Every instance method must accept `self` so Python can pass the instance automatically when the method is called. Without it, calling `f.book(2)` passes `f` as `seats` and raises a `TypeError`.
#
# </details>

# %% [markdown]
# ### Exercise 4.4 Predict the output
#
# What will this inheritance example print?
#
# ```python
# class Vehicle:
#     def __init__(self, make, speed_kmh):
#         self.make = make
#         self.speed_kmh = speed_kmh
#
#     def describe(self):
#         return f"{self.make} travelling at {self.speed_kmh} km/h"
#
# class ElectricVehicle(Vehicle):
#     def __init__(self, make, speed_kmh, range_km):
#         super().__init__(make, speed_kmh)
#         self.range_km = range_km
#
#     def describe(self):
#         base = super().describe()
#         return f"{base} (range: {self.range_km} km)"
#
# v = Vehicle("Toyota", 120)
# ev = ElectricVehicle("Tesla", 150, 500)
#
# print(v.describe())
# print(ev.describe())
# print(isinstance(ev, Vehicle))
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Toyota travelling at 120 km/h
# # Tesla travelling at 150 km/h (range: 500 km)
# # True
# ```
#
# `ElectricVehicle` calls `super().__init__()` to run the parent constructor, then adds `self.range_km`. Its `describe` method calls `super().describe()` to reuse the parent's string, then extends it. `isinstance(ev, Vehicle)` is `True` because `ElectricVehicle` inherits from `Vehicle`.
#
# </details>

# %% [markdown]
# ### Exercise 4.5 Adapt and extend
#
# The `Product` class below tracks stock level:
#
# ```python
# class Product:
#     def __init__(self, name, stock):
#         self.name = name
#         self.stock = stock
#
#     def sell(self, quantity):
#         self.stock -= quantity
# ```
#
# Extend it by:
# 1. Adding a `__str__` method that returns `"<name>: <stock> in stock"`.
# 2. Adding a `restock(quantity)` method that adds to the stock.
# 3. Creating a subclass `PerishableProduct` that also stores an `expiry_date` attribute and overrides `__str__` to include it.
#
# Test with the example below.
#
# Expected output:
# ```
# Milk: 20 in stock | Expires: 2026-05-01
# Bread: 12 in stock
# ```
#
# ```python
# class Product:
#     def __init__(self, name, stock):
#         self.name = name
#         self.stock = stock
#
#     def sell(self, quantity):
#         self.stock -= quantity
#
#     def restock(self, quantity):
#         # Your code here
#
#     def __str__(self):
#         # Your code here
#
# class PerishableProduct(Product):
#     # Your code here
#
# p1 = PerishableProduct("Milk", 15, "2026-05-01")
# p1.restock(5)
# p2 = Product("Bread", 10)
# p2.restock(2)
# print(p1)
# print(p2)
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
#     def restock(self, quantity):
#         self.stock += quantity
#
#     def __str__(self):
#         return f"{self.name}: {self.stock} in stock"
#
# class PerishableProduct(Product):
#     def __init__(self, name, stock, expiry_date):
#         super().__init__(name, stock)
#         self.expiry_date = expiry_date
#
#     def __str__(self):
#         return f"{self.name}: {self.stock} in stock | Expires: {self.expiry_date}"
# ```
#
# `__str__` is called automatically by `print()`. `PerishableProduct` calls `super().__init__()` to set `name` and `stock`, then stores the additional `expiry_date` attribute. Its `__str__` overrides the parent version to include the expiry date in the output.
#
# </details>

# %% [markdown]
# ---
# ## Section 5 – Error Handling

# %% [markdown]
# ### Exercise 5.1 Predict the output
#
# A configuration loader tries to read a setting. What will this block print?
#
# ```python
# config = {"timeout": 30, "retries": 3}
#
# try:
#     value = config["max_connections"]
#     print(f"Max connections: {value}")
# except KeyError:
#     print("Setting not found — using default")
# finally:
#     print("Config lookup complete")
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Setting not found — using default
# # Config lookup complete
# ```
#
# Accessing a dictionary with a key that does not exist raises a `KeyError`. The `except` block catches it and prints the fallback message. The `finally` block always runs — whether or not an exception occurred — so "Config lookup complete" prints in every case.
#
# </details>

# %% [markdown]
# ### Exercise 5.2 Fill in the blank
#
# Complete the function so it safely parses a latitude value from a string, returning `None` if the input is not a valid float.
#
# Expected output:
# ```
# 51.5074
# None
# None
# ```
#
# ```python
# def parse_latitude(value):
#     try:
#         lat = float(value)
#         if _______________:
#             raise ValueError("Latitude out of range")
#         return lat
#     except _______________:
#         return None
#
# print(parse_latitude("51.5074"))
# print(parse_latitude("not_a_number"))
# print(parse_latitude("200"))
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# if lat < -90 or lat > 90:
#     raise ValueError("Latitude out of range")
# except ValueError:
# ```
#
# `float("not_a_number")` raises a `ValueError`, which the `except` block catches. The explicit `raise ValueError` for out-of-range values is also caught by the same `except ValueError` handler. Catching `ValueError` specifically avoids hiding other unexpected errors.
#
# </details>

# %% [markdown]
# ### Exercise 5.3 Fix the bug
#
# The code is meant to open a file and handle the case where it does not exist, but it catches the wrong exception. Fix it.
#
# Expected output:
# ```
# File not found: data.csv
# ```
#
# ```python
# try:
#     with open("data.csv") as f:
#         content = f.read()
# except PermissionError as e:
#     print(f"File not found: data.csv")
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# except FileNotFoundError as e:
#     print(f"File not found: data.csv")
# ```
#
# Trying to open a file that does not exist raises a `FileNotFoundError`, not a `PermissionError`. `PermissionError` occurs when the file exists but you lack read access. Catching the wrong exception means the actual error is unhandled and propagates as a crash.
#
# </details>

# %% [markdown]
# ### Exercise 5.4 Predict the output
#
# Trace through each call carefully. Note which exception each input triggers.
#
# ```python
# def parse_record(data):
#     try:
#         parts = data.split(",")
#         name = parts[0]
#         age = int(parts[1])
#         return f"{name} is {age} years old"
#     except IndexError:
#         return "Missing field"
#     except ValueError:
#         return "Age must be a whole number"
#
# print(parse_record("Alice,30"))
# print(parse_record("Bob"))
# print(parse_record("Charlie,twenty"))
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Alice is 30 years old
# # Missing field
# # Age must be a whole number
# ```
#
# `"Alice,30"` splits and converts cleanly. `"Bob"` splits into a list with one element, so `parts[1]` raises an `IndexError` — caught by the first handler. `"Charlie,twenty"` splits fine but `int("twenty")` raises a `ValueError` — caught by the second handler. Multiple `except` blocks are checked in order.
#
# </details>

# %% [markdown]
# ### Exercise 5.5 Adapt and extend
#
# The function below converts a string to an integer, returning a default if it fails:
#
# ```python
# def safe_parse(value, default=0):
#     try:
#         return int(value)
#     except ValueError:
#         return default
# ```
#
# Extend it into a new function `safe_parse_list(values, default=0)` that takes a list of strings and returns a list of parsed integers, substituting the default for any that fail.
#
# Expected output:
# ```
# [10, 0, 42, 0, 7]
# ```
#
# ```python
# def safe_parse(value, default=0):
#     try:
#         return int(value)
#     except ValueError:
#         return default
#
# def safe_parse_list(values, default=0):
#     # Your code here
#
# print(safe_parse_list(["10", "abc", "42", "??", "7"]))
# ```

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# def safe_parse_list(values, default=0):
#     return [safe_parse(v, default) for v in values]
# ```
#
# Reusing `safe_parse` inside `safe_parse_list` keeps each function focused on one task. The list comprehension calls `safe_parse` for each string, collecting the results — valid integers where conversion succeeds, and the default value where it does not.
#
# </details>

# %% [markdown]
# ---
#
# ## Well done for completing Unit 2 exercises!
#
# If any section felt difficult, revisit the relevant part of the Unit 2 reading material before moving on.
#
# **Key reminders:**
#
# - Conditions in `if/elif/else` are evaluated from top to bottom — the first `True` branch runs and the rest are skipped, even if later conditions are also `True`
# - Python uses indentation to define code blocks — a statement in the wrong column changes the logic or causes an `IndentationError`
# - Every instance method must have `self` as its first parameter — without it, Python raises a `TypeError` when the method is called
# - A function without a `return` statement returns `None` — computing a value but not returning it discards it silently
# - Use specific exception types in `except` clauses — catching the wrong type leaves the real error unhandled and the program crashes
# - The `finally` block always runs, whether or not an exception occurred — use it for cleanup that must happen regardless
