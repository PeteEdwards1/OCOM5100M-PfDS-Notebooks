# %% [markdown]
# # Unit 1 – Practice & Consolidation Worksheet
#
# These exercises are for your own practice and are **not graded**. Work through them after completing the Unit 1 reading material. Attempt each exercise before revealing the answer.
#
# ## Exercise types
#
# | Type | What to do |
# |---|---|
# | Predict the output | Write what you think the code will print *before* running the cell |
# | Fix the bug | The code contains an error — find and correct it |
# | Fill in the blank | Complete the missing line(s) to produce the expected output |
# | Adapt and extend | A working example is given — modify it to solve a related problem |
#
# **Topics:** variables and data types · strings · NoneType · lists · tuples · dictionaries · sets

# %% [markdown]
# ## Section 1 – Variables, Data Types, and Operators

# %% [markdown]
# ### Exercise 1.1 Predict the output
#
# Read the code below. Before running it, write down what you think each line will print.

# %%
x = 10
y = 3

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x // y)
print(x % y)
print(x ** y)

# %% [markdown]
# <details>
# <summary><strong> Select here for answer</strong></summary>
#
# ```python
# # No fix needed — run the cell to check
# ```
#
# - `+`, `-`, `*` behave as expected
# - `/` always returns a **float**: `10 / 3` → `3.333...`
# - `//` is **floor division** — it discards the decimal: `10 // 3` → `3`
# - `%` is the **modulo** operator — it returns the remainder: `10 % 3` → `1`
# - `**` is **exponentiation**: `10 ** 3` → `1000`
#
# </details>

# %% [markdown]
# ### Exercise 1.2 Fill in the blank
#
# Complete the code to concatenate a first and last name and store the result in `full_name`.
#
# Expected output:
# ```
# Alan Turing
# ```

# %%
first_name = "Alan"
last_name = "Turing"

full_name = _______________

print(full_name)

# %% [markdown]
# <details>
# <summary><strong> Select here for answer</strong></summary>
#
# ```python
# full_name = first_name + " " + last_name
# ```
#
# String concatenation uses `+`. You must include the space `" "` as a separate string between the two names — Python will not add it automatically.
#
# </details>

# %% [markdown]
# ### Exercise 1.3 Fix the bug
#
# The code below is meant to store a boolean value, but it contains an error. Fix it so that `type(is_student)` prints `<class 'bool'>`.
#
# Expected output:
# ```
# <class 'bool'>
# ```

# %%
is_student = "True"

print(type(is_student))

# %% [markdown]
# <details>
# <summary><strong> Select here for answer</strong></summary>
#
# ```python
# is_student = True
# ```
#
# The original code stores the **string** `"True"` (in quotes), not the boolean `True`. Booleans in Python are written without quotes: `True` or `False`. Storing `"True"` as a string would cause logical errors if you later used it in a condition.
#
# </details>

# %% [markdown]
# ### Exercise 1.4 Predict the output
#
# What type will `result` be, and what will its value be?

# %%
a = 5
b = 2.0

result = a + b
print(type(result))
print(result)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# When you add an `int` and a `float`, Python automatically converts the result to a `float`. This is called **implicit type conversion**. `5 + 2.0` → `7.0` (float, not `7` int).
#
# </details>

# %% [markdown]
# ### Exercise 1.5 Adapt and extend
#
# The code below checks two conditions for a student.
#
# ```python
# age = 20
# is_enrolled = True
# print(age >= 18 and is_enrolled)  # True
# ```
#
# Extend it to add a third variable `has_paid = False` and print:
# 1. Whether the student meets **all three** conditions
# 2. Whether the student meets the first two but **has not yet paid**

# %%
age = 20
is_enrolled = True
has_paid = False

# Your code here

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# print(age >= 18 and is_enrolled and has_paid)      # False
# print(age >= 18 and is_enrolled and not has_paid)  # True
# ```
#
# `and` requires all conditions to be `True`. `not` inverts a boolean — `not False` → `True`. This pattern is useful for checking partial completion, such as a student who has enrolled but not yet paid.
#
# </details>

# %% [markdown]
# ---
# ## Section 2 – Strings

# %% [markdown]
# ### Exercise 2.1 Predict the output
#
# What will each line print?

# %%
s = "  Hello, World!  "

print(s.strip())
print(s.strip().lower())
print(s.strip().split(","))

# %% [markdown]
# <details>
# <summary><strong> Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `strip()` removes leading and trailing whitespace. `.lower()` converts to lowercase. `.split(",")` breaks the string at each comma and returns a list — note the space before `World!` is preserved inside the list item.
#
# </details>

# %% [markdown]
# ### Exercise 2.2 Fill in the blank
#
# Use string slicing to extract parts of the module code.
#
# Expected output:
# ```
# OCOM
# M
# 5100
# ```

# %%
module = "OCOM5100M"

print(module[___])   # first 4 characters
print(module[___])   # last character
print(module[___])   # characters at positions 4 to 7

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# print(module[:4])    # OCOM
# print(module[-1])    # M
# print(module[4:8])   # 5100
# ```
#
# Slicing uses `[start:end]` where `end` is **not included**. `[:4]` means from the beginning up to (not including) index 4. `[-1]` is the last character. `[4:8]` gives indices 4, 5, 6, 7.
#
# </details>

# %% [markdown]
# ### Exercise 2.3 Fix the bug
#
# The code below tries to get the number of characters in `text`, but it uses the wrong function. Fix it.
#
# Expected output:
# ```
# 11
# ```

# %%
text = "Programming"

print(text.size())

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# print(len(text))
# ```
#
# Strings do not have a `.size()` method — that causes an `AttributeError`. The correct function is `len()`, which works on strings, lists, tuples, dictionaries, and sets.
#
# </details>

# %% [markdown]
# ### Exercise 2.4 Predict the output
#
# What will each line print?

# %%
sentence = "the cat sat on the mat"

print(sentence.count("at"))
print(sentence.replace("cat", "dog"))
print(sentence.title())

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `count("at")` finds every occurrence of `"at"` in the string — it appears in `cat`, `sat`, and `mat`, so the answer is 3. `replace()` substitutes every match. `title()` capitalises the first letter of every word.
#
# </details>

# %% [markdown]
# ### Exercise 2.5 Adapt and extend
#
# The code below joins a list of words into a sentence.
#
# ```python
# words = ["data", "science", "is", "fun"]
# joined = " ".join(words)
# print(joined)  # data science is fun
# ```
#
# Extend it to also produce a new list called `upper_words` where every word is converted to uppercase.
#
# Expected output:
# ```
# data science is fun
# ['DATA', 'SCIENCE', 'IS', 'FUN']
# ```

# %%
words = ["data", "science", "is", "fun"]
joined = " ".join(words)

upper_words = _______________

print(joined)
print(upper_words)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# upper_words = []
# for w in words:
#     upper_words.append(w.upper())
# ```
#
# A `for` loop goes through each word in `words`, converts it to uppercase using `.upper()`, and adds it to the `upper_words` list using `.append()`. `" ".join()` does the reverse of `.split()` — it takes a list and joins elements with the given separator.
# </details>

# %% [markdown]
# ---
# ## Section 3 – NoneType

# %% [markdown]
# ### Exercise 3.1 Predict the output
#
# What will each line print?

# %%
val = None

print(val is None)
print(val == None)
print(bool(val))
print(type(val))

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `is None` and `== None` both return `True` here, but `is None` is the preferred style. `bool(None)` is `False` — `None` is **falsy** in Python, meaning it behaves like `False` in a condition. `type(None)` is `NoneType`, a special built-in type with exactly one value.
#
# </details>

# %% [markdown]
# ### Exercise 3.2 Fill in the blank
#
# Complete the function so it returns `None` when dividing by zero, and the result otherwise.
#
# Expected output:
# ```
# 5.0
# None
# ```

# %%
def safe_divide(a, b):
    if b == ___:
        return ___
    return a / b

print(safe_divide(10, 2))
print(safe_divide(10, 0))

# %% [markdown]
# <details>
# <summary><strong>Answer</strong></summary>
#
# ```python
# def safe_divide(a, b):
#     if b == 0:
#         return None
#     return a / b
# ```
#
# Returning `None` is a common pattern when a function cannot produce a meaningful result. The caller can then check `if result is None` before using the value.
#
# </details>

# %% [markdown]
# ### Exercise 3.3 Fix the bug
#
# The code below contains two errors related to `None`. Fix both.
#
# Expected output:
# ```
# x has no value
# ```

# %%
x = None

if x = None:
    print("x has no value")
else:
    print(f"x is {x}")

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# if x is None:
#     print("x has no value")
# ```
#
# Two bugs:
# 1. `x = None` inside an `if` condition uses a single `=` (assignment), which causes a `SyntaxError`. Comparisons use `==` or, for `None`, `is`.
# 2. The recommended way to check for `None` is `is None`, not `== None`. `is` checks identity (same object in memory), which is more precise for `None` since there is only ever one `None` object in Python.
#
# </details>

# %% [markdown]
# ### Exercise 3.4 Predict the output
#
# What will the code print?

# %%
results = [42, None, 17, None, 8]

valid = []
for r in results:
    if r is not None:
        valid.append(r)

print(valid)
print(len(valid))

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `r is not None` filters out any `None` values. The resulting list contains only the three actual numbers. This pattern is useful when processing data that may have missing values.
#
# </details>

# %% [markdown]
# ### Exercise 3.5 Adapt and extend
#
# Complete the function below so it handles a `None` score gracefully.
#
# Expected output:
# ```
# No score recorded
# Pass
# Fail
# ```

# %%
def get_grade(score):
    if _______________:
        return "No score recorded"
    elif score >= 70:
        return "Pass"
    else:
        return "Fail"

print(get_grade(None))
print(get_grade(85))
print(get_grade(55))

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# def get_grade(score):
#     if score is None:
#         return "No score recorded"
#     elif score >= 70:
#         return "Pass"
#     else:
#         return "Fail"
# ```
#
# Always check for `None` **before** comparing numerically. If you wrote `score >= 70` first, Python would raise a `TypeError` when `score` is `None` because you cannot compare `None` with a number.
#
# </details>

# %% [markdown]
# ---
# ## Section 4 – Lists

# %% [markdown]
# ### Exercise 4.1 Predict the output
#
# Trace through the list operations step by step.

# %%
lst = [10, 20, 30, 40, 50]

lst.insert(2, 99)
print(lst)

lst.remove(20)
print(lst)

print(lst.pop())
print(lst)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `insert(2, 99)` adds 99 at index 2, pushing existing elements right. `remove(20)` removes the first occurrence of the value 20. `pop()` removes and **returns** the last element — which is why it prints the removed value and then the shortened list.
#
# </details>

# %% [markdown]
# ### Exercise 4.2 Fill in the blank
#
# Sort the list in descending order and print the highest value.
#
# Expected output:
# ```
# [9, 8, 7, 5, 3, 2, 1]
# 9
# ```

# %%
numbers = [5, 3, 8, 1, 9, 2, 7]

numbers.sort(_______________)
print(numbers)
print(numbers[___])

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# numbers.sort(reverse=True)
# print(numbers)
# print(numbers[0])
# ```
#
# `sort()` sorts in ascending order by default. Passing `reverse=True` sorts in descending order. After sorting in descending order, the highest value is at index 0.
#
# </details>

# %% [markdown]
# ### Exercise 4.3 Fix the bug
#
# The code below causes an error when trying to access an element. Fix it.
#
# Expected output:
# ```
# blue
# ```

# %%
colours = ["red", "green", "blue"]

print(colours[3])

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# print(colours[2])
# ```
#
# List indices start at 0. A list with 3 elements has indices 0, 1, and 2. Trying to access index 3 raises an `IndexError: list index out of range`. `"blue"` is at index 2.
#
# **Note:** A more "Pythonic" way to get the last element without worrying about the exact length is to use `colours[-1]`. This avoids `IndexError` if you aren't sure how many items are in the list.
#
# </details>

# %% [markdown]
# ### Exercise 4.4 Predict the output
#
# Will changing `b` affect `a`? Think carefully before running.

# %%
a = [1, 2, 3]
b = a.copy()

b.append(4)

print(a)
print(b)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `a.copy()` creates a **shallow copy** — a new list with the same values. Changes to `b` do not affect `a`. Without `.copy()`, writing `b = a` would make both variables point to the **same** list, so appending to `b` would also modify `a`.
#
# **Warning:** If the list contained *nested* objects (like a list inside a list), a shallow copy would still share those inner objects. For simple values like integers, `.copy()` is perfectly safe!
# </details>

# %% [markdown]
# ### Exercise 4.5 Adapt and extend
#
# Split a list of scores into passing and failing using a for loop, then report how many are in each group and the highest and lowest overall scores.
#
# Expected output:
# ```
# Passing: 6, Failing: 2
# Highest: 95, Lowest: 55
# ```

# %%
scores = [72, 85, 91, 60, 78, 95, 55, 88]

passing = []
failing = []

for score in scores:
    if score >= ___:
        passing.___(score)
    else:
        failing.___(score)

print(f"Passing: {len(passing)}, Failing: {len(failing)}")
print(f"Highest: {max(scores)}, Lowest: {min(scores)}")

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# for score in scores:
#     if score >= 70:
#         passing.append(score)
#     else:
#         failing.append(score)
# ```
#
# A single for loop checks each score and appends it to either passing or failing depending on the condition. Using else means every score goes to exactly one group. max() and min() work directly on the original list.
#
# </details>

# %% [markdown]
# ---
# ## Section 5 – Tuples

# %% [markdown]
# ### Exercise 5.1 Predict the output
#
# What will each line print?

# %%
t = (1, 2, 3, 2, 1)

print(t.count(2))
print(t.index(3))
print(len(t))

# %% [markdown]
# <details>
# <summary><strong>Select here for Answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `count(2)` returns how many times 2 appears. `index(3)` returns the index of the **first** occurrence of 3. `len()` returns the total number of elements. Note that tuples support `.count()` and `.index()` but not `.append()` or `.remove()` — they are immutable.
#
# </details>

# %% [markdown]
# ### Exercise 5.2 Fill in the blank
#
# Unpack the tuple and use the values in an f-string.
#
# Expected output:
# ```
# x=4, y=7
# ```

# %%
point = (4, 7)

_______________ = point

print(f"x={x_coord}, y={y_coord}")

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# x_coord, y_coord = point
# ```
#
# Tuple unpacking assigns each element in order to a variable. The number of variables on the left must match the number of elements in the tuple.
#
# </details>

# %% [markdown]
# ### Exercise 5.3 Fix the bug
#
# The code tries to update the width of a screen resolution stored as a tuple, but tuples are immutable. Fix it by creating a new tuple with the updated value.
#
# Expected output:
# ```
# (2560, 1080)
# ```

# %%
dims = (1920, 1080)

dims[0] = 2560

print(dims)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# new_dims = (2560, dims[1])
# print(new_dims)
# ```
#
# Tuples cannot be modified — attempting to assign to an index raises a `TypeError`. The correct approach is to create a **new** tuple. `dims[1]` reuses the existing height value so you only have to specify what changed.
#
# **Why use tuples?** We use them for data that *should* stay together and stay constant (like coordinates or settings). It acts as a safety feature: if you accidentally try to change a value that should be fixed, Python will throw an error and alert you to the bug immediately.
#
# </details>

# %% [markdown]
# ### Exercise 5.4 Predict the output
#
# What will this loop print?

# %%
records = [("Alice", 85), ("Bob", 72), ("Charlie", 91)]

for name, score in records:
    print(f"{name}: {score}")

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# Each element of `records` is a tuple. When you write `for name, score in records`, Python unpacks each tuple automatically on each iteration. This is called **tuple unpacking in a loop** and is a very common Python pattern.
#
# </details>

# %% [markdown]
# ### Exercise 5.5 Adapt and extend
#
# Three colour values are stored as RGB tuples. Loop through them and print each channel.
#
# Expected output:
# ```
# R=255, G=0, B=0
# R=0, G=255, B=0
# R=0, G=0, B=255
# ```

# %%
rgb_red   = (255, 0, 0)
rgb_green = (0, 255, 0)
rgb_blue  = (0, 0, 255)

colours = [rgb_red, rgb_green, rgb_blue]

# Your code here

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# for c in colours:
#     r, g, b = c
#     print(f"R={r}, G={g}, B={b}")
# ```
#
# Unpack each tuple inside the loop using `r, g, b = c`. You could also write `for r, g, b in colours:` to unpack directly in the loop header — both approaches are correct.
#
# </details>

# %% [markdown]
# ---
# ## Section 6 – Dictionaries

# %% [markdown]
# ### Exercise 6.1 Predict the output
#
# What will each line print?

# %%
d = {"a": 1, "b": 2, "c": 3}

print(d.get("b"))
print(d.get("z", 0))
print("a" in d)
print("z" in d)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `get("b")` returns the value for key `"b"`. `get("z", 0)` returns the **default value** `0` because `"z"` does not exist — unlike `d["z"]` which would raise a `KeyError`. `in` checks whether a key exists in the dictionary.
#
# </details>

# %% [markdown]
# ### Exercise 6.2 Fill in the blank
#
# Add a new student to the dictionary and remove one.
#
# Expected output:
# ```
# {'Alice': 85, 'Charlie': 91, 'Diana': 78}
# ```

# %%
grades = {"Alice": 85, "Bob": 72, "Charlie": 91}

# Add Diana with a score of 78
grades[___] = ___

# Remove Bob
___ grades[___]

print(grades)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# grades["Diana"] = 78
# del grades["Bob"]
# ```
#
# `del` removes a key-value pair permanently. If the key does not exist, it raises a `KeyError`. An alternative is `grades.pop("Bob")`, which also removes the key but optionally returns its value.
#
# </details>

# %% [markdown]
# ### Exercise 6.3 Fix the bug
#
# The code should print each key and value, but it only iterates over keys. Fix it.
#
# Expected output:
# ```
# host: localhost
# port: 8080
# debug: True
# ```

# %%
config = {"host": "localhost", "port": 8080, "debug": True}

for key, value in config.keys():
    print(f"{key}: {value}")

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# for key, value in config.items():
# ```
#
# `config.keys()` returns only the keys, so you cannot unpack `key, value` from it — that raises a `ValueError`. `config.items()` returns key-value pairs as tuples, which can then be unpacked in the loop.
#
# </details>

# %% [markdown]
# ### Exercise 6.4 Predict the output
#
# This code builds a word frequency count. Trace through it carefully.

# %%
word_count = {}
words = ["the", "cat", "sat", "on", "the", "mat", "the"]

for word in words:
    word_count[word] = word_count.get(word, 0) + 1

print(word_count)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `word_count.get(word, 0)` returns the current count for `word`, or 0 if it has not been seen yet. Adding 1 then stores the updated count. After the loop, `"the"` appears 3 times, all other words appear once. This is a very common pattern for counting items in Python.
#
# </details>

# %% [markdown]
# ### Exercise 6.5 Adapt and extend
#
# Filter passing students into a new dictionary using a for loop, then calculate the class average.
#
# Expected output:
# ```
# {'Alice': 85, 'Bob': 72, 'Charlie': 91, 'Eve': 78}
# Class average: 78.8
# ```

# %%
students = {"Alice": 85, "Bob": 72, "Charlie": 91, "Diana": 68, "Eve": 78}

passed = {}
for name, score in students.___():
    if score >= ___:
        passed[___] = ___

total = 0
for score in students.___():
    total = total + score
average = total / len(___)

print(passed)
print(f"Class average: {average:.1f}")

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# passed = {}
# for name, score in students.items():
#     if score >= 70:
#         passed[name] = score
#
# total = 0
# for score in students.values():
#     total = total + score
# average = total / len(students)
# ```
#
# `.items()` gives access to both the key and value on each iteration, allowing the condition to check the score while storing the name. `.values()` returns just the scores, which are added to a running total using a for loop. Dividing by `len(students)` uses the full class count for the average, not just the passing students.
#
# </details>

# %% [markdown]
# ---
# ## Section 7 – Sets

# %% [markdown]
# ### Exercise 7.1 Predict the output
#
# Sets store only unique values. What will this code print?

# %%
s = {3, 1, 4, 1, 5, 9, 2, 6, 5}

print(len(s))
print(3 in s)
print(7 in s)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# Duplicate values (1 and 5 appear twice) are silently dropped, so the set contains 7 unique elements. `in` checks membership — `3 in s` is `True`, `7 in s` is `False`. Sets are unordered, so the printed representation may show elements in any order.
#
# </details>

# %% [markdown]
# ### Exercise 7.2 Fill in the blank
#
# Complete the code to show union, intersection, and symmetric difference of two sets.
#
# Expected output:
# ```
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3, 6, 7, 8}
# ```

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}

print(a ___ b)   # all elements from both
print(a ___ b)   # only elements in both
print(a ___ b)   # elements in either but not both

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# print(a | b)   # union
# print(a & b)   # intersection
# print(a ^ b)   # symmetric difference
# ```
#
# `^` is the symmetric difference operator — it returns elements that are in one set or the other, but **not** in both. It is the opposite of intersection.
#
#
# </details>

# %% [markdown]
# ### Exercise 7.3 Fix the bug
#
# The code tries to build a set of unique tags, but uses the wrong method. Fix it.
#
# Expected output (order may vary):
# ```
# {'python', 'data'}
# ```

# %%
unique_tags = set()

unique_tags.append("python")
unique_tags.append("data")
unique_tags.append("python")

print(unique_tags)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# unique_tags.add("python")
# unique_tags.add("data")
# unique_tags.add("python")
# ```
#
# Sets do not have an `.append()` method — that is a list method. Use `.add()` to add a single element to a set. Adding `"python"` twice has no effect because sets only store unique values.
#
# </details>

# %% [markdown]
# ### Exercise 7.4 Predict the output
#
# What will each set operation return?

# %%
enrolled_monday  = {"Alice", "Bob", "Charlie", "Diana"}
enrolled_tuesday = {"Bob", "Diana", "Eve", "Frank"}

print(enrolled_monday & enrolled_tuesday)
print(enrolled_monday | enrolled_tuesday)
print(enrolled_monday - enrolled_tuesday)

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# # Run the cell to verify
# ```
#
# `&` gives students enrolled on **both** days. `|` gives students enrolled on **at least one** day. `-` gives students enrolled on Monday **but not** Tuesday. Note that set output order may vary each time you run the cell.
#
# </details>

# %% [markdown]
# ### Exercise 7.5 Adapt and extend
#
# Use a set to remove duplicates from a list, then sort and report the results.
#
# Expected output:
# ```
# Original length: 10
# Unique values: [1, 2, 3, 4]
# Unique count: 4
# ```

# %%
list_with_dups = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

# Your code here

# %% [markdown]
# <details>
# <summary><strong>Select here for answer</strong></summary>
#
# ```python
# unique = list(set(list_with_dups))
# unique.sort()
# print(f"Original length: {len(list_with_dups)}")
# print(f"Unique values: {unique}")
# print(f"Unique count: {len(unique)}")
# ```
#
# Converting to a set removes duplicates instantly. Converting back to a list with `list()` gives you a sortable sequence. Note that `len(list_with_dups)` still returns 10 — the original list is unchanged.
#
# </details>

# %% [markdown]
# ---
#
# ## Well done for completing Unit 1 exercises!
#
# If any section felt difficult, revisit the relevant part of the Unit 1 reading material before moving on to Unit 2.
#
# **Key reminders:**
#
# - Every value has a type — use `type()` to check when unsure
# - `None` means the absence of a value — always check with `is None`
# - Strings are immutable sequences — use methods like `.strip()`, `.split()`, `.replace()` to work with them
# - Lists are ordered and mutable; tuples are ordered and immutable; sets are unordered and store only unique values
# - Dictionaries are looked up by key — use `.get()` to avoid `KeyError` when a key might not exist
